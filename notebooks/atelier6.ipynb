# %% [markdown]
# # Atelier 6 : Introduction au Clustering

# %% [markdown]
# ## Exercice 1 : Visualisation de données simples avec K-Means

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Générer des données aléatoires
np.random.seed(42)
X1 = np.random.normal(loc=[1, 1], scale=0.5, size=(100, 2))  # Cluster 1
X2 = np.random.normal(loc=[6, 6], scale=0.5, size=(100, 2))  # Cluster 2
X3 = np.random.normal(loc=[10, 1], scale=0.5, size=(100, 2))  # Cluster 3
X = np.vstack([X1, X2, X3])  # Empiler les données des 3 clusters

# Appliquer K-means
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X)
labels = kmeans.labels_
centers = kmeans.cluster_centers_

# Visualisation des clusters et des centres
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', marker='o')
plt.scatter(centers[:, 0], centers[:, 1], marker='X', color='red', s=200, label='Centres des clusters')
plt.title('Clustering K-Means (3 clusters)')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.show()

# Affichage du nombre de points par cluster
unique, counts = np.unique(labels, return_counts=True)
for i, count in zip(unique, counts):
    print(f"Cluster {i} : {count} points")

# Affichage des centres des clusters
print("Centres des clusters :")
print(centers)
# Out:
# Cluster 0 : 100 points
# Cluster 1 : 100 points
# Cluster 2 : 100 points
# Centres des clusters :
# [[6.06412436 6.02174382]
#  [9.97748131 0.93686366]
#  [0.94221787 1.01701116]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Génération d'un ensemble de points en 2D avec des clusters plus proches
np.random.seed(42)
X1 = np.random.normal(loc=[2, 2], scale=0.8, size=(100, 2))  # Cluster 1
X2 = np.random.normal(loc=[4, 4], scale=0.8, size=(100, 2))  # Cluster 2
X3 = np.random.normal(loc=[6, 2], scale=0.8, size=(100, 2))  # Cluster 3
X = np.vstack([X1, X2, X3])  # Empiler les données des 3 clusters

# Appliquer K-Means avec 3 clusters
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X)
labels = kmeans.labels_
centers = kmeans.cluster_centers_

# Visualisation des clusters et des centres
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', marker='o')
plt.scatter(centers[:, 0], centers[:, 1], marker='X', color='red', s=200, label='Centres des clusters')
plt.title('Clustering K-Means (3 clusters proches)')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.show()

# Affichage du nombre de points par cluster
unique, counts = np.unique(labels, return_counts=True)
for i, count in zip(unique, counts):
    print(f"Cluster {i} : {count} points")

# Affichage des centres des clusters
print("Centres des clusters :")
print(centers)
# Out:
# Cluster 0 : 95 points
# Cluster 1 : 104 points
# Cluster 2 : 101 points
# Centres des clusters :
# [[4.04689488 4.10257468]
#  [5.96903486 1.93527391]
#  [1.90274384 2.03055348]]

# %% [markdown]
# ### **Questions :**
#
# #### 1. **Combien de points appartiennent à chaque cluster ?**
# - **Cas 1 : Clusters espacés**
#   Chaque cluster contient environ **100 points**, car les données sont générées de manière relativement uniforme. Les résultats de K-Means devraient être assez équilibrés, avec des clusters distincts.
#
# - **Cas 2 : Clusters plus proches**
#   Les points dans chaque cluster peuvent ne pas être exactement **100**, en raison de la proximité des clusters et de l'assignation des points par K-Means. Certains clusters pourraient avoir un nombre légèrement supérieur ou inférieur de points, mais en général, la répartition est relativement proche de 100 points par cluster.
#
# #### 2. **Que remarquez-vous concernant la position des centres des clusters ?**
# - **Cas 1 : Clusters espacés**
#   Les centres des clusters sont bien séparés, chacun étant proche du centre de son propre groupe de points. K-Means parvient à bien séparer les groupes en fonction de leurs caractéristiques, avec des centres nettement distincts.
#
# - **Cas 2 : Clusters plus proches**
#   Les centres des clusters sont plus rapprochés les uns des autres, ce qui peut rendre plus difficile la séparation nette entre les clusters. K-Means place les centres là où la distance entre les points est la plus faible, ce qui peut entraîner une certaine "fusion" de clusters si les points sont trop proches les uns des autres.

# %% [markdown]
# ## Exercice 2 : Variation du nombre de clusters (kk)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Génération d'un ensemble de points en 2D avec des clusters plus proches
np.random.seed(42)
X1 = np.random.normal(loc=[2, 2], scale=0.8, size=(100, 2))  # Cluster 1
X2 = np.random.normal(loc=[4, 4], scale=0.8, size=(100, 2))  # Cluster 2
X3 = np.random.normal(loc=[6, 2], scale=0.8, size=(100, 2))  # Cluster 3
X = np.vstack([X1, X2, X3])  # Empiler les données des 3 clusters

# Liste des valeurs de k à tester
k_values = [2, 3, 4]

# Initialisation de la figure pour les graphiques
plt.figure(figsize=(15, 5))

# Application de K-Means pour chaque valeur de k
for i, k in enumerate(k_values, 1):
    # Application de K-Means
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    labels = kmeans.labels_
    centers = kmeans.cluster_centers_

    # Subplot pour chaque valeur de k
    plt.subplot(1, 3, i)
    plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', marker='o')
    plt.scatter(centers[:, 0], centers[:, 1], marker='X', color='red', s=200, label='Centres des clusters')
    plt.title(f'K-Means (k={k})')
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.legend()

# Affichage des graphiques
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Questions :**
#
# #### 1. **Quel k semble le plus adapté ? Pourquoi ?**
# - **k=3** semble être le plus adapté, car il correspond mieux aux trois clusters naturels présents dans les données. Avec cette valeur de **k**, K-Means parvient à bien séparer les points en trois groupes distincts, ce qui reflète mieux la structure réelle des données.
#
# #### 2. **Quels problèmes peuvent survenir si k est mal choisi ?**
# - **k trop petit (par exemple, k=2)** : Les clusters naturels peuvent être fusionnés en un nombre trop faible de groupes, ce qui entraîne une perte d'information et des segments non représentatifs des données.
# - **k trop grand (par exemple, k=4)** : Le modèle peut sur-segmenter les données, créant des clusters artificiels qui ne correspondent pas aux groupes réels. Cela peut entraîner une perte de généralisation et une mauvaise interprétation des données.

# %% [markdown]
# ## Exercice 3 : Segmentation des clients avec un petit dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import pandas as pd

# Génération d'un petit dataset fictif avec des données d'Âge et de Dépenses
np.random.seed(42)
age = np.random.randint(18, 65, 300)  # Âge des clients entre 18 et 65 ans
depenses = np.random.randint(100, 1000, 300)  # Dépenses entre 100 et 1000

# Créer un DataFrame avec les données
data = pd.DataFrame({
    'Âge': age,
    'Dépenses': depenses
})

# Application de K-Means avec k=3
kmeans = KMeans(n_clusters=3, random_state=42)
data['Cluster'] = kmeans.fit_predict(data[['Âge', 'Dépenses']])

# Visualisation des clusters
plt.figure(figsize=(8, 6))
plt.scatter(data['Âge'], data['Dépenses'], c=data['Cluster'], cmap='viridis', marker='o')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red', marker='X', label='Centres des clusters')
plt.title('Segmentation des clients par Âge et Dépenses (k=3)')
plt.xlabel('Âge')
plt.ylabel('Dépenses')
plt.legend()
plt.show()

# %% [markdown]
# ### **Questions :**
#
# #### 1. **Quels groupes peuvent être identifiés ?**
# - Avec **k=3**, trois groupes distincts de clients sont identifiés. Les groupes sont répartis selon l'**Âge** et les **Dépenses** des clients. Le clustering permet de séparer les clients en trois segments, bien que la séparation exacte dépende de la distribution des données.
#
# #### 2. **Quelles hypothèses pouvez-vous tirer par rapport au comportement des clients de chaque groupe ?**
# - **Groupe 1** : Clients jeunes ayant des dépenses plus faibles, ce qui pourrait refléter un pouvoir d'achat limité ou un comportement de consommation plus restreint.
# - **Groupe 2** : Clients d'âge moyen, avec des dépenses modérées à élevées. Ce groupe pourrait correspondre à des clients ayant un revenu stable mais pas encore maximal.
# - **Groupe 3** : Clients plus âgés ayant des dépenses élevées. Ce groupe pourrait refléter des clients plus établis financièrement, avec une capacité d'achat plus grande.
#
# ### Conclusion :
# - K-Means avec **k=3** a permis de segmenter les clients en groupes distincts basés sur **l'Âge** et les **Dépenses**. Les hypothèses sur le comportement des clients peuvent être faites selon les caractéristiques de chaque groupe.
